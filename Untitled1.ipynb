# %% [markdown]
# <a href="https://colab.research.google.com/github/MDeluteAgrazamendez/sampleproject01/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""import json

with open("students.json", "r") as file:
    data = json.load(file)

print(data)

for student in data["students"]:
    print(student["grades"])

import json

# Open the JSON file
with open("/content/students.json") as f:
    students = json.load(f)

# Display the JSON content
print(students)
"""

import requests
import json

url = "https://raw.githubusercontent.com/MDeluteAgrazamendez/sampleproject01/refs/heads/main/students.json"
response = requests.get(url)
students = response.json()

print(students)
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
cred = credentials.Certificate("/content/firebase_key.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://grade8-json-db-default-rtdb.asia-southeast1.firebasedatabase.app/'
})
print("Connected to Firebase!")
# Out:
# Connected to Firebase!

# %%
import json

data = students

print("JSON file loaded")
ref = db.reference("students")
for student in data["students"]:
    ref.child(str(student["id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
students_ref = db.reference("students")
students_data = students_ref.get()
print(students_data)
# Out:
# {'1001': {'grades': {'CS': 88, 'Math': 92}, 'id': 1001, 'name': 'Czarina'}, '1002': {'grades': {'CS': 90, 'Math': 85}, 'id': 1002, 'name': 'Miguel'}}

# %%
for student_id, info in students_data.items():
  print(info["name"])
# Out:
# Czarina
# Miguel

# %%
for student_id, info in students_data.items():
    print(info["name"], info["grades"])
# Out:
# Czarina {'CS': 88, 'Math': 92}
# Miguel {'CS': 90, 'Math': 85}

# %%
for student_id, info in students_data.items():
    grades = info["grades"]
    average = sum(grades.values()) / len(grades)
    print(info["name"], "- Average:", average)
# Out:
# Czarina - Average: 90.0
# Miguel - Average: 87.5

# %%
# Fetch data from Firebase
students_data = ref.get()  # returns a dictionary with keys "0", "1", ...

# Loop through each student
for key, student in students_data.items():
    name = student["name"]
    grades = student["grades"].values()
    avg = sum(grades) / len(grades)

    print(f"Student: {name}")
    print(f"Grades: {student['grades']}")
    print(f"Average: {avg:.2f}\n")
# Out:
# Student: Czarina
# Grades: {'CS': 88, 'Math': 92}
# Average: 90.00
#
# Student: Miguel
# Grades: {'CS': 90, 'Math': 85}
# Average: 87.50
